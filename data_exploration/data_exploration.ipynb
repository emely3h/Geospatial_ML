# %% [markdown]
# # Data Exploration + Splitting Algorithm for overlapping tiles

# %% [markdown]
# The goal of this notebook is to compare the original images before they are split into tiles. When training the model on the entire dataset the dataset is split into training data, validation data and test data. When evaluating the model based on calculated metrics it is important to use data that the model has never seen before. As experiment two shows that it is beneficial if the tiles in which the images are split overlap it is crucial that tiles of the same original images don't appear in e.g. training data and test data. Therefore it is necessary to analyze the images in order to come up with a good training-, validation- and test split of the dataset.

# %% [markdown]
# The entire dataset consists of 16 images taken on the following dates:
# - 2022_12_12
# - 2022_12_02
# - 2022_10_23
# - 2022_10_13
# - 2022_09_18
# - 2022_09_13
# - 2022_09_08
# - 2022_09_03
# - 2022_08_24
# - 2022_08_14
# - 2022_08_04
# - 2022_07_30
# - 2022_07_25
# - 2022_07_15
# - 2022_07_10
# - 2022_06_20
#
# All images have been split with a tile size of 256 and a step size of 200.
#
# The goal is to explore the following parameters:
# - amount of tiles per image
# - amount of pixels per class per image
#
# in order to come up with a good solution of splitting the dataset.

# %% [markdown]
# ### 0. Get Stats for each image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls
# %cd drive/MyDrive/MachineLearning/Geospatial_ML
! ls
# Out:
# drive  sample_data
# /content/drive/.shortcut-targets-by-id/15HUD3sGdfvxy5Y_bjvuXgrzwxt7TzRfm/MachineLearning/Geospatial_ML
# architecture.drawio	 evaluation   notebooks     requirements.txt
# combine_npz_files.ipynb  experiments  prepare_data
# data_exploration	 models       README.md

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %%
def check_shapes(x_input, y_mask):
  if not x_input.shape[0] == y_mask.shape[0]:
    raise TypeError('amount of tiles different in input and mask array.')
  if not (x_input.shape[1] == 256 and x_input.shape[2] == 256):
    raise TypeError('tile size of input array does not match 256')
  if not (x_input.shape[3] == 5):
    raise TypeError('input array does not have 5 channels')
  if not (y_mask.shape[1] == 256 and y_mask.shape[2] == 256):
    raise TypeError('tile size of mask array does not match 256')

# %%
def num_of_pixels_per_class(y_mask, label):
  flatten = np.reshape(y_mask, (-1,))
  pixel_match = (flatten == label)
  pix_per_class = np.count_nonzero(pixel_match)
  return pix_per_class

# %%
def data_exploration(x_input, y_mask, file_name):

  check_shapes(x_input, y_mask)

  num_tiles = x_input.shape[0]
  num_pixels = x_input.shape[0] * x_input.shape[1] * x_input.shape[2]

  num_land_pix = num_of_pixels_per_class(y_mask, 2)
  num_valid_pix = num_of_pixels_per_class(y_mask, 1)
  num_invalid_pix = num_of_pixels_per_class(y_mask, 0)

  if not num_pixels == (num_land_pix + num_valid_pix + num_invalid_pix):
    raise TypeError('pixels per class summed up is not equal to num_pixels.')

  percenetage_land = 100/ num_pixels * num_land_pix
  percenetage_valid = 100/ num_pixels * num_valid_pix
  percenetage_invalid = 100/ num_pixels * num_invalid_pix

  return {
      'file_name': file_name,
      'x_input.shape': x_input.shape,
      'y_mask.shape': y_mask.shape,
      'num_tiles': num_tiles,
      'num_pixels': num_pixels,
      'num_land_pix': num_land_pix,
      'num_valid_pix': num_valid_pix,
      'num_invalid_pix': num_invalid_pix,
      'percenetage_land': percenetage_land,
      'percenetage_valid': percenetage_valid,
      'percenetage_invalid': percenetage_invalid
  }

# %%
data_directory = "../data_colab/256_200"

all_stats = []

for file_name in os.listdir(data_directory):
  if file_name.startswith('2022'):
    tiles_path = os.path.join(data_directory, file_name)

    y_mask  = np.load(tiles_path)['y_mask']
    x_input = np.load(tiles_path)['x_input']

    print(file_name)
    print(y_mask.shape)
    print(x_input.shape)
    print()

    stats = data_exploration(x_input, y_mask, file_name)
    all_stats.append(stats)
# Out:
# 2022_10_23.npz
# (1164, 256, 256)
# (1164, 256, 256, 5)
#
# 2022_12_12.npz
# (957, 256, 256)
# (957, 256, 256, 5)
#
# 2022_12_02.npz
# (1142, 256, 256)
# (1142, 256, 256, 5)
#
# 2022_10_13.npz
# (889, 256, 256)
# (889, 256, 256, 5)
#
# 2022_09_03.npz
# (1196, 256, 256)
# (1196, 256, 256, 5)
#
# 2022_09_08.npz
# (927, 256, 256)
# (927, 256, 256, 5)
#
# 2022_08_24.npz
# (1306, 256, 256)
# (1306, 256, 256, 5)
#
# 2022_08_14.npz
# (1179, 256, 256)
# (1179, 256, 256, 5)
#
# 2022_09_13.npz
# (1175, 256, 256)
# (1175, 256, 256, 5)
#
# 2022_07_30.npz
# (1183, 256, 256)
# (1183, 256, 256, 5)
#
# 2022_07_25.npz
# (1258, 256, 256)
# (1258, 256, 256, 5)
#
# 2022_07_15.npz
# (864, 256, 256)
# (864, 256, 256, 5)
#
# 2022_09_18.npz
# (1174, 256, 256)
# (1174, 256, 256, 5)
#
# 2022_06_20.npz
# (1251, 256, 256)
# (1251, 256, 256, 5)
#
# 2022_08_04.npz
# (1319, 256, 256)
# (1319, 256, 256, 5)
#
# 2022_07_10.npz
# (1323, 256, 256)
# (1323, 256, 256, 5)

# %% [markdown]
# ### 1. Display stats

# %%
df = pd.DataFrame(all_stats)
df.shape
# Out:
# (16, 11)

# %%
# sort by num tiles
df_num_tiles = df[['file_name', 'num_tiles', 'percenetage_valid', 'percenetage_invalid', 'percenetage_land']]
df_num_tiles_sorted = df_num_tiles.sort_values(by='num_tiles')
df_num_tiles_sorted
# Out:
#          file_name  num_tiles  percenetage_valid  percenetage_invalid  \
# 11  2022_07_15.npz        864          10.050526            50.681909
# 3   2022_10_13.npz        889          16.807331            39.782475
# 5   2022_09_08.npz        927          31.447306            24.559434
# 1   2022_12_12.npz        957          21.371911            28.253614
# 2   2022_12_02.npz       1142          17.023361            35.459047
# 0   2022_10_23.npz       1164          10.701117            43.796029
# 12  2022_09_18.npz       1174          48.241497             7.988471
# 8   2022_09_13.npz       1175          46.242989            10.073545
# 7   2022_08_14.npz       1179          47.804025             8.449461
# 9   2022_07_30.npz       1183          52.403293             3.372690
# 4   2022_09_03.npz       1196           5.212303            52.216682
# 13  2022_06_20.npz       1251          42.293231            10.844996
# 10  2022_07_25.npz       1258          46.570370             6.644759
# 6   2022_08_24.npz       1306          27.908288            26.841526
# 14  2022_08_04.npz       1319          37.760050            13.440227
# 15  2022_07_10.npz       1323          30.300570            26.719039
#
#     percenetage_land
# 11         39.267565
# 3          43.410194
# 5          43.993260
# 1          50.374475
# 2          47.517591
# 0          45.502853
# 12         43.770031
# 8          43.683466
# 7          43.746515
# 9          44.224017
# 4          42.571015
# 13         46.861773
# 10         46.784871
# 6          45.250187
# 14         48.799723
# 15         42.980391

# %%
mean_tiles = df['num_tiles'].mean()
print(f'Mean number of tiles: {mean_tiles}')
# Out:
# Mean number of tiles: 1144.1875

# %%
# sort by ratio invalid valid
df_ratio = df[['file_name', 'percenetage_valid', 'percenetage_invalid', 'percenetage_land', 'num_tiles']]
df_ratio_sorted = df_ratio.sort_values(by='percenetage_valid')
df_ratio_sorted
# Out:
#          file_name  percenetage_valid  percenetage_invalid  percenetage_land  \
# 4   2022_09_03.npz           5.212303            52.216682         42.571015
# 11  2022_07_15.npz          10.050526            50.681909         39.267565
# 0   2022_10_23.npz          10.701117            43.796029         45.502853
# 3   2022_10_13.npz          16.807331            39.782475         43.410194
# 2   2022_12_02.npz          17.023361            35.459047         47.517591
# 1   2022_12_12.npz          21.371911            28.253614         50.374475
# 6   2022_08_24.npz          27.908288            26.841526         45.250187
# 15  2022_07_10.npz          30.300570            26.719039         42.980391
# 5   2022_09_08.npz          31.447306            24.559434         43.993260
# 14  2022_08_04.npz          37.760050            13.440227         48.799723
# 13  2022_06_20.npz          42.293231            10.844996         46.861773
# 8   2022_09_13.npz          46.242989            10.073545         43.683466
# 10  2022_07_25.npz          46.570370             6.644759         46.784871
# 7   2022_08_14.npz          47.804025             8.449461         43.746515
# 12  2022_09_18.npz          48.241497             7.988471         43.770031
# 9   2022_07_30.npz          52.403293             3.372690         44.224017
#
#     num_tiles
# 4        1196
# 11        864
# 0        1164
# 3         889
# 2        1142
# 1         957
# 6        1306
# 15       1323
# 5         927
# 14       1319
# 13       1251
# 8        1175
# 10       1258
# 7        1179
# 12       1174
# 9        1183

# %%
mean_perc_invalid = df['percenetage_invalid'].mean()
print(f'Mean percentage of invalid pixels: {mean_perc_invalid}')

print(f'Total amount of tiles: {df["num_tiles"].sum()}')
print(f'Total amount of invalid pixels: {df["num_invalid_pix"].sum()}')
# Out:
# Mean percentage of invalid pixels: 24.320244004101355
# Total amount of tiles: 18307
# Total amount of invalid pixels: 280566117

# %% [markdown]
# ### 2. Splitting algorithm

# %%
def _validate(df, total_tiles, total_invalids, threshold, target):

  df_num_tiles = df['num_tiles'].sum()
  df_num_invalides = df['num_invalid_pix'].sum()


  percentage_tiles = 100 / total_tiles * df_num_tiles
  percentage_invalides = 100 / total_invalids * df_num_invalides

  if (target + threshold) >= percentage_tiles <= (target - threshold):
    return False
  elif (target + threshold) >= percentage_invalides <= (target - threshold):
    return False
  else:
    print(f'Total_tiles: {total_tiles} total_invalids: {total_invalids}')
    print(f'percentage_tiles: {percentage_tiles}, percentage_invalides: {percentage_invalides} ')
    print()
    
    return True

def splitting_algorithm(threshold, df):
  total_tiles = df['num_tiles'].sum()
  total_invalids = df['num_invalid_pix'].sum()

  df_copy = df.copy()

  valid = False
  count = 0
  
  while not valid:
    print(f'Count: {count}')
    df_copy = df.copy()

    training_set = df_copy.sample(n=10)
    df_copy = df_copy.drop(training_set.index)
    
    validation_set = df_copy.sample(n=3)
    df_copy = df_copy.drop(validation_set.index)

    test_set = df_copy.sample(n=3)
    df_copy = df_copy.drop(test_set.index)

    train_validate = _validate(training_set, total_tiles, total_invalids, threshold, 60)
    val_validate = _validate(validation_set, total_tiles, total_invalids, threshold, 20)
    test_validate = _validate(test_set, total_tiles, total_invalids, threshold, 20)

    if train_validate and val_validate and test_validate:
      valid = True
    else:
      training_set = None
      validation_set= None
      test_set= None
      count += 1

  return training_set, validation_set, test_set

training_set, validation_set, test_set = splitting_algorithm(1, df)
# Out:
# Count: 0
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.571366144097883, percentage_invalides: 21.897624223811743
#
# Count: 1
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.997815043426012, percentage_invalides: 22.355551222886973
#
# Count: 2
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.85612060960288, percentage_invalides: 62.18910247098725
#
# Count: 3
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.29819194843502, percentage_invalides: 73.44681432077559
#
# Count: 4
# Count: 5
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.73015786311247, percentage_invalides: 29.554989706757784
#
# Count: 6
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 65.67433222264707, percentage_invalides: 72.68814858352978
#
# Count: 7
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.35904298902059, percentage_invalides: 65.83299044624123
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.079750914950562, percentage_invalides: 24.966637008416807
#
# Count: 8
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.823018517506963, percentage_invalides: 19.305012515107087
#
# Count: 9
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.88343256677773, percentage_invalides: 63.240615758316956
#
# Count: 10
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.7246954716775, percentage_invalides: 29.664535721539032
#
# Count: 11
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.54514666521003, percentage_invalides: 73.28731430531221
#
# Count: 12
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 59.45266837821598, percentage_invalides: 76.15245642794422
#
# Count: 13
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.78510952094827, percentage_invalides: 74.79060167482733
#
# Count: 14
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.11208827224559, percentage_invalides: 69.91779980331694
#
# Count: 15
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.45190364341508, percentage_invalides: 62.04955996165424
#
# Count: 16
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.473370841754516, percentage_invalides: 64.22576429640647
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.95411591194625, percentage_invalides: 21.028128282503904
#
# Count: 17
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.117987654995357, percentage_invalides: 34.75252786850238
#
# Count: 18
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.48899328125853, percentage_invalides: 64.38466873032996
#
# Count: 19
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.71409843229365, percentage_invalides: 68.93187105697442
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.19992352651991, percentage_invalides: 19.660535844390647
#
# Count: 20
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.59316108592341, percentage_invalides: 62.99714587417553
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.046976566340742, percentage_invalides: 21.096862170281238
#
# Count: 21
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.89364723876113, percentage_invalides: 31.033028482195515
#
# Count: 22
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.34811820615065, percentage_invalides: 62.71492148854168
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.78478177746217, percentage_invalides: 20.521518640827182
#
# Count: 23
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.30955372261976, percentage_invalides: 29.26027628632006
#
# Count: 24
# Count: 25
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.0091221936964, percentage_invalides: 23.557332120756406
#
# Count: 26
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.741410389468506, percentage_invalides: 63.55703600517093
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.172611569345058, percentage_invalides: 25.035370896194138
#
# Count: 27
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 65.46129895668324, percentage_invalides: 60.425723110392546
#
# Count: 28
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.08046102583711, percentage_invalides: 75.85659390224943
#
# Count: 29
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.096138089255476, percentage_invalides: 30.63638186930462
#
# Count: 30
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.598678101272736, percentage_invalides: 25.90422420822825
#
# Count: 31
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.484677992024906, percentage_invalides: 64.2602235536517
#
# Count: 32
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.893592614846774, percentage_invalides: 61.645921413953204
#
# Count: 33
# Count: 34
# Count: 35
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.17916643906702, percentage_invalides: 68.03122523879104
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.391489594144314, percentage_invalides: 19.679404124197934
#
# Count: 36
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 65.2100289506746, percentage_invalides: 64.05407428438694
#
# Count: 37
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.916589282788, percentage_invalides: 67.64331417824056
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.571366144097883, percentage_invalides: 21.897624223811743
#
# Count: 38
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.21155842027639, percentage_invalides: 76.39664200791573
#
# Count: 39
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.534221882340084, percentage_invalides: 64.01701243204646
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.325558529524223, percentage_invalides: 23.265216661925002
#
# Count: 40
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.189381111050416, percentage_invalides: 26.81129168565996
#
# Count: 41
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.676244059649314, percentage_invalides: 73.16165265957613
#
# Count: 42
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.28688479816464, percentage_invalides: 66.23280743483362
#
# Count: 43
# Count: 44
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.708636040858686, percentage_invalides: 64.8590545949638
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.790244168897143, percentage_invalides: 20.41197262604593
#
# Count: 45
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.38559021139454, percentage_invalides: 65.55857562800429
#
# Count: 46
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 21.565521385262468, percentage_invalides: 20.58629731116106
#
# Count: 47
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.4023597530999, percentage_invalides: 68.66325380266784
#
# Count: 48
# Count: 49
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.72972087179767, percentage_invalides: 61.02976575749523
#
# Count: 50
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.009449937182495, percentage_invalides: 75.35000493306181
#
# Count: 51
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.22286557054678, percentage_invalides: 71.85881715004096
#
# Count: 52
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.6970011471022, percentage_invalides: 24.237062809690592
#
# Count: 53
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.76325995520838, percentage_invalides: 74.03799404615917
#
# Count: 54
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.65947451794395, percentage_invalides: 67.93512846029087
#
# Count: 55
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 59.75856229857431, percentage_invalides: 70.08737979575773
#
# Count: 56
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.172939312831154, percentage_invalides: 68.74557414928331
#
# Count: 57
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.129294805265744, percentage_invalides: 35.95430876637181
#
# Count: 58
# Count: 59
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.71994319112907, percentage_invalides: 62.44641864576968
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.363795269569017, percentage_invalides: 22.04871053620491
#
# Count: 60
# Count: 61
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.25017752772163, percentage_invalides: 76.5491030408351
#
# Count: 62
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.81673676735674, percentage_invalides: 61.64651236200414
#
# Count: 63
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.6598568853444, percentage_invalides: 59.866607484894544
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.93226634620637, percentage_invalides: 22.423102145295754
#
# Count: 64
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.68055934888294, percentage_invalides: 63.927379370617295
#
# Count: 65
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 65.32473917080898, percentage_invalides: 70.0132051226984
#
# Count: 66
# Count: 67
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.64854973507401, percentage_invalides: 66.04370085073387
#
# Count: 68
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.10662588081061, percentage_invalides: 67.7051263463863
#
# Count: 69
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.3469711039493, percentage_invalides: 78.2065544286661
#
# Count: 70
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.336483312394165, percentage_invalides: 19.66845982332214
#
# Count: 71
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 65.18817938493471, percentage_invalides: 71.98058523937871
#
# Count: 72
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.0910034413066, percentage_invalides: 60.29744069202768
#
# Count: 73
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.30403670727044, percentage_invalides: 64.21901508513231
#
# Count: 74
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.80116895176708, percentage_invalides: 25.507577595337356
#
# Count: 75
# Count: 76
# Count: 77
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.823346260993056, percentage_invalides: 65.14601119849408
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.02512700060086, percentage_invalides: 22.49183603307309
#
# Count: 78
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.08554104987163, percentage_invalides: 66.98659695960365
#
# Count: 79
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.01458458513137, percentage_invalides: 24.131472012352795
#
# Count: 80
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.37974545255912, percentage_invalides: 66.48833365719639
#
# Count: 81
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.293876659201395, percentage_invalides: 74.71627409663299
#
# Count: 82
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.40274212050035, percentage_invalides: 66.62587271719627
#
# Count: 83
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.037144261757796, percentage_invalides: 71.21123111241548
#
# Count: 84
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.64854973507401, percentage_invalides: 77.30093723327253
#
# Count: 85
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.23264325121538, percentage_invalides: 76.94289399885018
#
# Count: 86
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.916206915387555, percentage_invalides: 65.2147450862714
#
# Count: 87
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.08554104987163, percentage_invalides: 62.76732696129518
#
# Count: 88
# Count: 89
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.266182334626095, percentage_invalides: 63.05496147989958
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.396569618178837, percentage_invalides: 19.217804550504578
#
# Count: 90
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.718796088927725, percentage_invalides: 74.42521364759095
#
# Count: 91
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.17807396078003, percentage_invalides: 25.60951078779053
#
# Count: 92
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.86666302507237, percentage_invalides: 73.88619631500264
#
# Count: 93
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.72464084776315, percentage_invalides: 68.57620123815592
#
# Count: 94
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.030917135521925, percentage_invalides: 70.60852790003862
#
# Count: 95
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.70355601682416, percentage_invalides: 70.94706949235784
#
# Count: 96
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.26579996722565, percentage_invalides: 64.26030695645262
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.21669306822527, percentage_invalides: 24.706491554003293
#
# Count: 97
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 65.78358005134648, percentage_invalides: 65.69081219454593
#
# Count: 98
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.28764953296553, percentage_invalides: 72.7198216882333
#
# Count: 99
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.8604358988365, percentage_invalides: 67.95051449494879
#
# Count: 100
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.035614792156, percentage_invalides: 59.913166563872714
#
# Count: 101
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.189381111050416, percentage_invalides: 26.81129168565996
#
# Count: 102
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.440978860545144, percentage_invalides: 62.78365537631901
#
# Count: 103
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.49052275086032, percentage_invalides: 70.39898442191435
#
# Count: 104
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.139782596820886, percentage_invalides: 64.6822021634209
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.150762003605177, percentage_invalides: 20.919224896996383
#
# Count: 105
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.32550390560987, percentage_invalides: 71.45881446546875
#
# Count: 106
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.12962254875184, percentage_invalides: 59.03360418963206
#
# Count: 107
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.631780193368655, percentage_invalides: 62.68032144451712
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.24362265799967, percentage_invalides: 19.59972593554481
#
# Count: 108
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.59900584475883, percentage_invalides: 72.42890879799288
#
# Count: 109
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.452286010815534, percentage_invalides: 63.90609561738347
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.904954389031516, percentage_invalides: 20.042851432412988
#
# Count: 110
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.254875184355704, percentage_invalides: 71.4757580652549
#
# Count: 111
# Count: 112
# Count: 113
# Count: 114
# Count: 115
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.24362265799967, percentage_invalides: 19.59972593554481
#
# Count: 116
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.00327743486098, percentage_invalides: 22.92969111448336
#
# Count: 117
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.091385808707045, percentage_invalides: 71.21504411739069
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.778937018626753, percentage_invalides: 19.210191728176497
#
# Count: 118
# Count: 119
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.697328890588295, percentage_invalides: 69.39703520935139
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.194843502485387, percentage_invalides: 20.590345554805534
#
# Count: 120
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 63.38559021139454, percentage_invalides: 65.55857562800429
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.883104823291635, percentage_invalides: 20.480706513823264
#
# Count: 121
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 59.39804446386628, percentage_invalides: 62.67525846679483
#
# Count: 122
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.73556563063309, percentage_invalides: 70.46152868131257
#
# Count: 123
# Count: 124
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 64.63101545856776, percentage_invalides: 60.536675923700365
#
# Count: 125
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.98213798000764, percentage_invalides: 63.02176217522374
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.500355055443272, percentage_invalides: 25.945036335232167
#
# Count: 126
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 61.998142786912105, percentage_invalides: 68.8802358126516
#
# Count: 127
# Count: 128
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.107062872125415, percentage_invalides: 25.10292181860292
#
# Count: 129
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 62.954061288031895, percentage_invalides: 64.74926514380209
#
# Count: 130
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 60.037144261757796, percentage_invalides: 59.10665755836796
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 20.150762003605177, percentage_invalides: 20.919224896996383
#
# Total_tiles: 18307 total_invalids: 280566117
# percentage_tiles: 19.812093734637024, percentage_invalides: 19.974117544635654

# %%
print('Training Set Images')
print(training_set['file_name'])
print()
print('Validation Set Images')
print(validation_set['file_name'])
print()
print('Test Set Images')
print(test_set['file_name'])
print()
# Out:
# Training Set Images
# 13    2022_06_20.npz
# 8     2022_09_13.npz
# 1     2022_12_12.npz
# 15    2022_07_10.npz
# 10    2022_07_25.npz
# 5     2022_09_08.npz
# 3     2022_10_13.npz
# 11    2022_07_15.npz
# 0     2022_10_23.npz
# 9     2022_07_30.npz
# Name: file_name, dtype: object
#
# Validation Set Images
# 14    2022_08_04.npz
# 4     2022_09_03.npz
# 12    2022_09_18.npz
# Name: file_name, dtype: object
#
# Test Set Images
# 2    2022_12_02.npz
# 7    2022_08_14.npz
# 6    2022_08_24.npz
# Name: file_name, dtype: object

# %% [markdown]
# - In total we have 16 images. When applying a 60-20-20 split this means we will use 10 image for training, 3 images for validation and 3 images for testing.
#
# - To find the best split two parameters are relevant, the number of tiles to achieve the 60-20-20 split and the number of invalid pixels.
#
# - The algorithm comes up with possible solutions until it finds one where the amount of tiles and the amount of invalid pixels differs max 1% from the target 60-20-20 split

# %% [markdown]
# ### 3. Results
#
# #### Training Set Images
#
# 60.03 % of total tiles, 59.11 % of total invalid pixels
#
# - 2022_06_20.npz
# - 2022_09_13.npz
# - 2022_12_12.npz
# - 2022_07_10.npz
# - 2022_07_25.npz
# - 2022_09_08.npz
# - 2022_10_13.npz
# - 2022_07_15.npz
# - 2022_10_23.npz
# - 2022_07_30.npz
#
#
#
# #### Validation Set Images
#
# 20.15 % of total tiles, 29.92 % of total invalid pixels
#
# - 2022_08_04.npz
# - 2022_09_03.npz
# - 2022_09_18.npz
#
#
# #### Test Set Images
#
# 19.81 % of total tiles, 19.97 % of total invalid pixels
#
# - 2022_12_02.npz
# - 2022_08_14.npz
# - 2022_08_24.npz
